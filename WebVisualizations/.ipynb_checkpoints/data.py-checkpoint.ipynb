# %%
import pandas as pd

# %%
#csv file

df= pd.read_csv('cities.csv')

# %%
#save to html

df.to_html('data.html', index=False)

# %%
#will create an html format from the csv
table= df.to_html()
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>luanda</td>
#       <td>3</td>
#       <td>AO</td>
#       <td>1563902863</td>
#       <td>83</td>
#       <td>-8.83</td>
#       <td>13.24</td>
#       <td>73.40</td>
#       <td>5.82</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>dikson</td>
#       <td>5</td>
#       <td>RU</td>
#       <td>1563902930</td>
#       <td>90</td>
#       <td>73.51</td>
#       <td>80.55</td>
#       <td>34.72</td>
#       <td>2.95</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>hithadhoo</td>
# ...
